# %% [markdown]
# ---
# # **SALES PREDICTION**
#
# Done By,
#
# Saisubramanian V
#
# ---
#
#
# ### IMPORTING MODULES
#
# Problem Statement
#
# *Create a model that forecasts sales based on the amounts spent on various marketing channels.*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ## Understanding the Data By EDA

# %%
df = pd.read_csv('advertising.csv')

df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_9, *['TV'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...

# %%
df.shape
# Out:
# (200, 4)

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# TV           0.0
# Radio        0.0
# Newspaper    0.0
# Sales        0.0
# dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
sns.pairplot(df, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', kind='scatter')
plt.show()

# %%
plt.hist(df['TV'])
plt.xlabel('TV')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Radio'],color='green')
plt.xlabel('Radio')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Newspaper'],color='red')
plt.xlabel('Newspaper')
plt.ylabel('Frequency')
plt.show()

# %%
sns.heatmap(df.corr(),annot= True)
# Out:
# <Axes: >

# %% [markdown]
# ***The variable TV appears to be most linked with Sales, as seen from the pairplot and the heatmap. So let's run a straightforward linear regression with TV as the feature variable.***

# %% [markdown]
# ## Train-Test Split

# %%
x_train,x_test,y_train,y_test = train_test_split(df[['TV']], df[['Sales']], test_size=0.2, random_state=0)

# %%
print(x_train)
# Out:
#         TV
# 134   36.9
# 66    31.5
# 26   142.9
# 113  209.6
# 168  215.4
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [160 rows x 1 columns]

# %%
print(y_train)
# Out:
#      Sales
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [160 rows x 1 columns]

# %%
print(x_test)
# Out:
#         TV
# 18    69.2
# 170   50.0
# 107   90.4
# 98   289.7
# 177  170.2
# 182   56.2
# 5      8.7
# 146  240.1
# 12    23.8
# 152  197.6
# 61   261.3
# 125   87.2
# 180  156.6
# 154  187.8
# 80    76.4
# 7    120.2
# 33   265.6
# 130    0.7
# 37    74.7
# 74   213.4
# 183  287.6
# 145  140.3
# 45   175.1
# 159  131.7
# 60    53.5
# 123  123.1
# 179  165.6
# 185  205.0
# 122  224.0
# 44    25.1
# 16    67.8
# 55   198.9
# 150  280.7
# 111  241.7
# 22    13.2
# 189   18.7
# 129   59.6
# 4    180.8
# 83    68.4
# 106   25.0

# %%
print(y_test)
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# 5      7.2
# 146   18.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   15.5
# 154   20.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    16.1
# 159   12.9
# 60     8.1
# 123   15.2
# 179   17.6
# 185   22.6
# 122   16.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     17.9
# 83    13.6
# 106    7.2

# %% [markdown]
# ## Model Building

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
plt.plot(pred)

# %%
print(pred)
# Out:
# [[10.92912965]
#  [ 9.88399105]
#  [12.08313684]
#  [22.93189318]
#  [16.42699412]
#  [10.22148373]
#  [ 7.63585439]
#  [20.23195181]
#  [ 8.45781235]
#  [17.91849399]
#  [21.38595901]
#  [11.90894708]
#  [15.68668762]
#  [17.38503783]
#  [11.32105662]
#  [13.70527904]
#  [21.62002651]
#  [ 7.20037998]
#  [11.22851831]
#  [18.77855596]
#  [22.81758114]
#  [14.7994085 ]
#  [16.6937222 ]
#  [14.33127351]
#  [10.07451111]
#  [13.86313851]
#  [16.17659633]
#  [18.32130782]
#  [19.35555956]
#  [ 8.52857694]
#  [10.85292163]
#  [17.98925858]
#  [22.44198446]
#  [20.3190467 ]
#  [ 7.88080875]
#  [ 8.18019741]
#  [10.40656035]
#  [17.00399772]
#  [10.88558221]
#  [ 8.52313351]]

# %% [markdown]
# ## Model Evaluvation

# %%
model.coef_
# Out:
# array([[0.0544343]])

# %%
model.intercept_
# Out:
# array([7.16227597])

# %%
# Example for proof
0.0544343 * 69.2 + 7.16227597
# Out:
# 10.929129529999999

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,0.0544343 * x_test + 7.16227597, 'r')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(pred, y_test, edgecolors=(0, 0, 1))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
plt.show()

# %%
mae = metrics.mean_absolute_error(y_test, pred)
mse = metrics.mean_squared_error(y_test, pred)
r2 = metrics.r2_score(y_test, pred)

print("The model performance for testing set")
print("--------------------------------------")
print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# MAE is 2.01486731475948
# MSE is 6.639091226559302
# R2 score is 0.8010943934328406
